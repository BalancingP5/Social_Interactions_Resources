# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from scipy import integrate, optimize
from sklearn.cluster import DBSCAN
from bisect import bisect_left
from collections import namedtuple
from multiprocessing import Pool

# %%
n = 25                  # Number of agents
p = 2                   # Exponent for transport cost
lambda_param = 20       # Default transport cost weight
sigma = 0.2             # Default kernel width
n_iter = 400            # Maximum number of iterations for optimization
np.random.seed(5)

bounds = [(0, 1) for i in range(n)]       # Boundary of agents

def uniform_rho(x):
    return 1 if 0 < x < 1 else 0

rho = uniform_rho  # Use uniform resource distribution

# %%
def neg_inv_quad(r, sigma):
    return -(1/(1+(r**2)/(sigma**2)))

def pop_k(x, sigma):
    total = 0.0
    n = len(x)
    for i in range(n):
        for j in range(n):
            d = np.abs(x[i] - x[j])
            total += neg_inv_quad(d, sigma)
    return total

# %%
kx_space = np.linspace(0, 1, 101)
pk_space = [neg_inv_quad(x, sigma) for x in kx_space]

plt.figure()
plt.plot(kx_space, pk_space, color='darkorange')
plt.plot(sigma, neg_inv_quad(sigma, sigma), 'go')
plt.axvline(x=sigma, color='darkgray', linestyle='--', linewidth=1.5, label=r'$\sigma$')
plt.xlabel("Distance z")
plt.ylabel("K(z)")
plt.legend(["Kernel", f"σ = {sigma}"])
plt.title("Negative Inverse Quadratic Kernel")
plt.show()

# %%
def territories():
    return [k / n for k in range(n + 1)]

T = territories()

# %%
def energy(x, borders, lambda_param, sigma):
    pop_energy = pop_k(x, sigma)
    transport_energy = 0.0
    for i in range(n):
        integrand = lambda y: np.abs(x[i] - y)**p * rho(y)
        cost, _ = integrate.quad(integrand, borders[i], borders[i + 1])
        transport_energy += cost
    return (1 / (2 * n**2)) * pop_energy + (lambda_param / 2) * transport_energy

# %%
def dbscan_cities(agents, a_sigma, min_pop=2):
    X = np.array(agents).reshape(-1, 1)
    db = DBSCAN(eps=a_sigma, min_samples=min_pop, metric='euclidean')
    labels = db.fit_predict(X)
    cities, pops = [], []
    for cluster_id in set(labels):
        if cluster_id == -1:
            continue
        members = X[labels == cluster_id].ravel()
        pops.append(len(members))
        cities.append(members.mean())
    return np.array(cities), np.array(pops)

# %%
def initial_guess(run,seed=15410):
    rng = np.random.default_rng(seed)
    if (run == 0):
      x0 = 0.5*np.ones(n)
      x0 += rng.random(n) * 0.04
    elif (run == 1):
      x0 = np.array([0.4]*12 + [0.5] + [0.6]*12)
      x0 += rng.random(n) * 0.02
    elif (run == 2):
      x0 = np.array(sum(([x*0.1]*5 for x in range(3,8)),[]))
      x0 += rng.random(n) * 0.01
    else:
      x0 = np.linspace(0, 1, n) + rng.random(n) * 0.002 * run
        
    x0 = np.sort(x0)
    x0 = np.clip(x0, 0, 1)
    return x0

TrialResult = namedtuple('TrialResult', ('energy', 'cities', 'x', 'length'))

def trial(args):
    (sig, lam, run) = args
    seed = hash((sig, lam, run)) & (2**32-1)
    x0 = initial_guess(run,seed)
    res = optimize.minimize(lambda x: energy(x, T, lam, sig), x0=x0,
                            method='L-BFGS-B', bounds = bounds,
                            options={'maxiter': n_iter})
    energy_value = res.fun
    cities, pops = dbscan_cities(res.x, 0.5/25)
    num_cities = len(cities)
    length = sum(cities[i+1]-cities[i] for i in range(num_cities-1))/(num_cities-1) if num_cities > 1 else None
    return TrialResult(energy_value, num_cities, res.x, length)

def trial_runs(args):
    (sig, lam) = args
    trial_results = map(trial, zip([sig]*6,[lam]*6,range(6)))
    best_trial = min(trial_results, key=lambda t: t.energy)
    return best_trial.cities, best_trial.length

def vary_parameters(sigma_values, lambda_values):
    city_count_grid = np.zeros((len(sigma_values), len(lambda_values)))
    city_length_grid = np.zeros((len(sigma_values), len(lambda_values)))
    with Pool() as p:
        for i, sig in enumerate(sigma_values):
            city_counts, city_lengths = zip(*p.map(trial_runs, zip([sig]*len(lambda_values),lambda_values)))
            city_count_grid[i] = np.array(city_counts)
            city_length_grid[i] = np.array(city_lengths)
    return city_count_grid, city_length_grid

# %%
cities, lengths = vary_parameters(np.linspace(0.05,0.05,1),np.logspace(-1,8,19,base=2))
# Out:
# (array([[1.]]), array([[nan]]))

# %%
# Define ranges for σ and λ.
sigma_range = np.linspace(0.01, 0.10, 37)
lambda_range = np.logspace(-1, 8, 19, base=2)
results_grid, lengths_grid = vary_parameters(sigma_range, lambda_range)

# %%
Lambda, Sigma   = np.meshgrid(lambda_range, sigma_range)
sigma_vals      = Sigma.flatten()
lambda_vals     = Lambda.flatten()
results         = results_grid.flatten()

# mask for the zeros
zero_mask = (results == 0)

# bins for the plot
min_count = int(np.min(results[~zero_mask]))
max_count = int(np.max(results[~zero_mask]))
# create integer bins [0.5,1.5), [1.5,2.5), ..., [M-0.5, M+0.5)
bins = np.arange(min_count - 0.5, max_count + 1.5, 1.0)

# viridis colormap
cmap = plt.cm.viridis
# create a norm which maps each bin to a discrete color
norm = BoundaryNorm(bins, ncolors=cmap.N, clip=True)

plt.figure(figsize=(8, 4))

# non-zero points with discrete viridis
sc = plt.scatter(sigma_vals[~zero_mask], lambda_vals[~zero_mask],
    c=results[~zero_mask],
    cmap=cmap,
    norm=norm,
    s=50,
    alpha=0.7
)

# zeros in red
plt.scatter(
    sigma_vals[zero_mask],
    lambda_vals[zero_mask],
    color='red',
    s=50,
    alpha=0.7,
    label='Zero cities'
)

# discretized colorbar
cb = plt.colorbar(sc, boundaries=bins, ticks=np.arange(min_count, max_count+1))
cb.set_label("Number of Cities")

# overlay λ = 2/σ line
sigma_line  = np.linspace(sigma_range.min(), sigma_range.max(), 500)
lambda_line = 2.0 / sigma_line
plt.plot(
    sigma_line,
    lambda_line,
    linestyle=':',
    color='black',
    linewidth=2,
    label=r'$\lambda = \frac{2}{\sigma}$'
)

plt.xlabel("σ")
plt.ylabel("λ")
plt.yscale('log')
plt.title("Scatter Plot: λ vs σ Colored by Number of Cities")
plt.legend(loc='lower right')
plt.show()

# %%
# Define ranges for σ and λ.
sigma_range = np.linspace(0.04, 0.08, 9)
lambda_range = np.logspace(2.5, 5, 11, base=2)
results_grid, lengths_grid = vary_parameters(sigma_range, lambda_range)

# %%
min((trial((0.08,lambda_range[8],i)) for i in range(6)),key=lambda t: t.energy)
# Out:
# TrialResult(energy=-0.10561068676362616, cities=2, x=array([0.08823462, 0.11124731, 0.13036371, 0.14886041, 0.16845117,
#        0.19130005, 0.22330575, 0.33110211, 0.35957032, 0.38270138,
#        0.40623738, 0.43638535, 0.5215771 , 0.55888688, 0.58641145,
#        0.61099922, 0.63595549, 0.66668316, 0.77979424, 0.81008476,
#        0.83204371, 0.85111893, 0.86929579, 0.88823282, 0.91115669]), length=0.7204421632012432)

# %%
np.where(np.isclose(sigma_range,0.04,atol=1e-5))
# Out:
# (array([0]),)

# %%
plt.plot(lambda_range, lengths_grid[0], label=r'$\sigma = 0.04$')
plt.plot(lambda_range, lengths_grid[1], label=r'$\sigma = 0.045$')
plt.plot(lambda_range, lengths_grid[2], label=r'$\sigma = 0.05$')
plt.plot(lambda_range, lengths_grid[3], label=r'$\sigma = 0.055$')
plt.plot(lambda_range, lengths_grid[4], label=r'$\sigma = 0.06$')
plt.plot(lambda_range, lengths_grid[5], label=r'$\sigma = 0.065$')
plt.plot(lambda_range, lengths_grid[6], label=r'$\sigma = 0.07$')
plt.plot(lambda_range, lengths_grid[7], label=r'$\sigma = 0.075$')
#plt.plot(lambda_range, lengths_grid[8], label=r'$\sigma = 0.08$')
plt.xlabel("λ")
plt.xscale("log")
plt.ylabel("L")
plt.legend(loc='upper right')
